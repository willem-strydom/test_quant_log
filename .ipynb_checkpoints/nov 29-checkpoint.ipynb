# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from experiment import experiment
from experiment import test_loss
import random
scaler = MinMaxScaler(feature_range=(-1, 1))

from gen_data import gen_data
X,y = gen_data()
X = scaler.fit_transform(X)

bias = np.ones((X.shape[1],1)).T
X = np.vstack((bias, X)).astype(float)

experiment(X,y)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 16
#      13 bias = np.ones((X.shape[1],1)).T
#      14 X = np.vstack((bias, X)).astype(float)
# ---> 16 experiment(X,y)
#
# File ~/PycharmProjects/test_quant_log/experiment.py:33, in experiment(X, y)
#      31 loss_grid = np.zeros((4,4))
#      32 for i, level_w in enumerate(levels):
# ---> 33     for j, level_q in enumerate(levels):
#      34         start = time.time()
#      35         w, iters = grdescentquant(func, w0, 0.1, 10000, X, y, level_w, level_q, type_w, type_q, tolerance=1e-02)
#
# File ~/PycharmProjects/test_quant_log/GrdDscntQuant.py:28, in grdescentquant(func, w0, stepsize, maxiter, xTr, yTr, level_w, level_q, type_w, type_q, tolerance)
#      23 # Increase the stepsize by a factor of 1.01 each iteration where the loss goes down,
#      24 # and decrease it by a factor 0.5 if the loss went up. ...
#      25 # also undo the last update in that case to make sure
#      26 # the loss decreases every iteration
#      27 while num_iter < maxiter:
# ---> 28     loss, gradient = func(w, xTr, yTr, level_q,type_q)
#      29     if loss > prior_loss:
#      31         w = w + stepsize * prior_gradient
#
# File ~/PycharmProjects/test_quant_log/QuantLog.py:36, in quantlogistic(w, xTr, yTr, num_bins, type)
#      32 vals = func(vals)
#      34 # then quantize
# ---> 36 beta = quantize(vals, num_bins, type)
#      37 gradient = -np.mean(yTr * xTr * beta, axis = 1).reshape(-1, 1)
#      39 # store the values for later analysis of distribution...
#
# File ~/PycharmProjects/test_quant_log/quantize.py:38, in quantize(vals, level_q, type_q)
#      35     # in general
#      36     else:
#      37         beta[i] = ((partitions[a - 1]) + (partitions[a]))/2
# ---> 38     i += 1
#      40 return beta
#
# KeyboardInterrupt:

# %%
#loading and sorting the data
diabetes_data = pd.read_csv("diabetes.csv").to_numpy()
diabetes_x = diabetes_data[:,:-1]
diabetes_y = diabetes_data[:,-1]
diabetes_y = np.where(diabetes_y == 0,-1, diabetes_y)
# avoid overflow error

diabetes_x = scaler.fit_transform(diabetes_x)
bias = np.ones((diabetes_x.shape[0],1))
diabetes_x = np.hstack((bias,diabetes_x))
experiment(diabetes_x.T,diabetes_y.T)

# %%
#mse for different levels
import numpy as np
from QuantLog import quantlogistic
from NormalLog import normallogistic
from sklearn.metrics import mean_squared_error
quantizers = ['unif', 'gauss']
levels = [1,2,3,4]
func = quantlogistic
w0 = np.random.uniform(-1, 1, (X.shape[0], 1))
mse_grid = np.zeros((2,4))
for i,type_q in enumerate(quantizers):
    for j, level_q in enumerate(levels):
        loss, grad_q = quantlogistic(w0,X,y,level_q, type_q)
        loss, grad = normallogistic(w0,X,y)
        mse = mean_squared_error(grad,grad_q)
        print(mse,type_q)
        mse_grid[i,j] = mse
# Out:
# 0.00015236758610752583 unif
# 2.1516948797658308e-05 unif
# 5.276289090215684e-06 unif
# 2.1229449025692054e-06 unif
# 0.0012273093698518004 gauss
# 0.0011399852181626423 gauss
# 0.0006560864574498696 gauss
# 0.0004981991442456525 gauss

# %%
import matplotlib.pyplot as plt
xlabel = "gradient lvl"

plt.pcolormesh(mse_grid)
plt.colorbar()
plt.ylabel('bottom -> unif, top -> gaus')
plt.xlabel(xlabel)
plt.title('mse for different quantizers and levels')
plt.show()

# %%
fig, ax = plt.subplots()

# Set the bar width
bar_width = 0.35
data1 = mse_grid[0,:]
data2 = mse_grid[1,:]

# Set the positions of the bars on the x-axis
bar_positions1 = np.arange(4)
bar_positions2 = bar_positions1 + bar_width

# Plot the bars for each set of data
ax.bar(bar_positions1, data1, width=bar_width, label='uniform')
ax.bar(bar_positions2, data2, width=bar_width, label='gaussian')

# Add labels, title, and legend
ax.set_xticks(bar_positions1 + bar_width / 2)
ax.set_xticklabels(range(1,5))
ax.set_ylabel('MSE')
ax.set_title('MSE of gradient vs unif or gaus quantized gradient on random W0')
ax.legend()

# Show the plot
plt.show()

# %%
from GrdDscnt import grdescentnormal
from NormalLog import normallogistic
w, iters = grdescentnormal(normallogistic, w0, 0.01, 10000, X, y, tolerance=1e-02)
def test_loss(w,X,y):
    #calculates test loss
    log_odds = np.dot(w.T, X)
    probs = 1 / (1 + np.exp(-log_odds))
    preds = (probs > 0.5).astype(int)
    preds = np.where(preds == 0, -1, preds)
    test_loss = np.sum(preds != y) / len(y)

    return test_loss
loss = test_loss(w,X,y)
print(loss,iters)
# Out:
# 0.0186 506
